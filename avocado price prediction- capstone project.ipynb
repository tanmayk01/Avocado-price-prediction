# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
data=pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-2/master/Projects/avocado.csv',index_col=0)

# %%
df=data.copy()

# %%
df
# Out:
#           Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0   2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1   2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2   2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3   2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4   2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ..         ...           ...           ...      ...        ...     ...
# 7   2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 8   2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 9   2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 10  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 11  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['AveragePrice'])
plt.subplot(1,2,2)
sns.distplot(df['AveragePrice'])
plt.show()

# %%
sns.boxplot(df['AveragePrice'])

# %%
def remove_outlier(df,col,k=2):
    mean=df[col].mean()
    global df1
    sd=df[col].std()
    final_Df=[x for x in df[col] if (x > mean - k *sd)]
    final_Df=[x for x in df[col] if (x > mean + k *sd)]
    df1=df.loc[df[col].isin(final_Df)];print(df1.shape);return df1

# %%
remove_outliers(df,'AveragePrice')
# Out:
# (18168, 13)
#           Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0   2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1   2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2   2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3   2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4   2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ..         ...           ...           ...      ...        ...     ...
# 7   2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 8   2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 9   2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 10  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 11  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df.groupby('region').sum()
# Out:
#                      AveragePrice  Total Volume          4046          4225  \
# region
# Albany                     527.63  1.606780e+07  6.165396e+05  1.271597e+07
# Atlanta                    452.23  8.860512e+07  4.938750e+07  1.055186e+07
# BaltimoreWashington        518.57  1.347139e+08  1.205180e+07  8.314222e+07
# Boise                      455.67  1.441319e+07  6.766594e+06  1.170049e+06
# Boston                     517.44  9.727398e+07  1.688178e+06  7.240631e+07
# BuffaloRochester           512.69  2.296247e+07  6.005149e+05  1.070242e+07
# California                 471.62  1.028982e+09  3.989670e+08  3.514914e+08
# Charlotte                  542.84  3.555554e+07  7.563811e+06  1.238027e+07
# Chicago                    526.19  1.337023e+08  1.084408e+07  8.602744e+07
# CincinnatiDayton           408.71  4.452201e+07  1.829154e+06  2.063791e+07
# Columbus                   423.44  2.999336e+07  1.258613e+07  5.715680e+06
# ...

# %%
df['region'].value_counts()
# Out:
# PhoenixTucson          338
# NewOrleansMobile       338
# Southeast              338
# NewYork                338
# Portland               338
# RaleighGreensboro      338
# GreatLakes             338
# MiamiFtLauderdale      338
# Philadelphia           338
# Boston                 338
# GrandRapids            338
# Syracuse               338
# Albany                 338
# SanDiego               338
# Jacksonville           338
# NorthernNewEngland     338
# SouthCarolina          338
# Denver                 338
# Houston                338
# HartfordSpringfield    338
# RichmondNorfolk        338
# Tampa                  338
# LasVegas               338
# Northeast              338
# Orlando                338
# Indianapolis           338
# West                   338
# Charlotte              338
# BaltimoreWashington    338
# SouthCentral           338
# CincinnatiDayton       338
# Midsouth               338
# Plains                 338
# Louisville             338
# ...

# %%
plt.figure(figsize=(15,15))
plt.title('Avg Price by region')
sns.barplot(df['AveragePrice'],df['region'])

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
sns.barplot(df['type'],df['AveragePrice'])
plt.title('Price wrt type')
# Out:
# Text(0.5, 1.0, 'Price wrt type')

# %%
df.groupby('year')['AveragePrice'].value_counts()
# Out:
# year  AveragePrice
# 2015  1.03            85
#       0.98            83
#       0.99            81
#       1.09            78
#       1.08            77
#                       ..
# 2018  2.16             1
#       2.18             1
#       2.22             1
#       2.27             1
#       2.30             1
# Name: AveragePrice, Length: 835, dtype: int64

# %%
corre=df.corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(corre,annot=True)

# %%
df['Avg_Price']=df['AveragePrice']
df=df.drop(columns={'AveragePrice'})

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df
# Out:
#           Date  Total Volume     4046       4225    4770  Total Bags  \
# 0   2015-12-27      64236.62  1036.74   54454.85   48.16     8696.87
# 1   2015-12-20      54876.98   674.28   44638.81   58.33     9505.56
# 2   2015-12-13     118220.22   794.70  109149.67  130.50     8145.35
# 3   2015-12-06      78992.15  1132.00   71976.41   72.58     5811.16
# 4   2015-11-29      51039.60   941.48   43838.39   75.78     6183.95
# ..         ...           ...      ...        ...     ...         ...
# 7   2018-02-04      17074.83  2046.96    1529.20    0.00    13498.67
# 8   2018-01-28      13888.04  1191.70    3431.50    0.00     9264.84
# 9   2018-01-21      13766.76  1191.92    2452.79  727.94     9394.11
# 10  2018-01-14      16205.22  1527.63    2981.04  727.01    10969.54
# 11  2018-01-07      17489.58  2894.77    2356.13  224.53    12014.15
#
#     Small Bags  Large Bags  XLarge Bags          type  year            region  \
# ...

# %%
df=df.drop(['Date'],axis=1)
df=df.drop(['Total Bags'],axis=1)

# %%
fruit_type=df['type']
region=df['region']

# %%
fruit_type.value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['type']=le.fit_transform(df.type)
df['region']=le.fit_transform(df.region)

# %%
fruit_type=pd.DataFrame({'fruit_type':fruit_type,'code':df['type']})
region=pd.DataFrame({'region':region,'code':df['region']})

# %%
fruit_type
# Out:
#       fruit_type  code
# 0   conventional     0
# 1   conventional     0
# 2   conventional     0
# 3   conventional     0
# 4   conventional     0
# ..           ...   ...
# 7        organic     1
# 8        organic     1
# 9        organic     1
# 10       organic     1
# 11       organic     1
#
# [18249 rows x 2 columns]

# %%
region
# Out:
#               region  code
# 0             Albany     0
# 1             Albany     0
# 2             Albany     0
# 3             Albany     0
# 4             Albany     0
# ..               ...   ...
# 7   WestTexNewMexico    53
# 8   WestTexNewMexico    53
# 9   WestTexNewMexico    53
# 10  WestTexNewMexico    53
# 11  WestTexNewMexico    53
#
# [18249 rows x 2 columns]

# %%
##Sampling

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df,test_size = 0.2,random_state= 100)
x_train=train.iloc[:,0:-1]
y_train=train.iloc[:,-1]
x_test=test.iloc[:,0:-1]
y_test=test.iloc[:,-1]

# %%
##model building

# %%
from sklearn.linear_model import LinearRegression
ln=LinearRegression()

# %%
x_train
# Out:
#     Total Volume       4046       4225      4770  Small Bags  Large Bags  \
# 14     255258.55    9811.16   31012.00    108.75   214282.33       44.31
# 49       1219.69     454.04      41.71      0.00      559.94      164.00
# 26     478874.92   15053.53  279488.30  21092.23   150878.19     9866.32
# 13       2975.53      33.26     445.60      0.00     2496.67        0.00
# 22     436208.03  158304.49  172990.41  12492.00    92385.74       35.39
# ..           ...        ...        ...       ...         ...         ...
# 26     170194.95    8951.42   43472.34   1596.01   106878.45     9296.73
# 27     554763.76  449311.47   30231.78    678.40    55484.76    19010.81
# 30       2206.16       5.29    1132.48      0.00      473.33      595.06
# 30      28707.18    1397.86   25119.52      0.00     2186.47        3.33
# 24     102461.61    2468.78   86707.66   2546.08     4950.13     4788.96
#
#     XLarge Bags  type  year  region
# 14         0.00     1  2017      29
# ...

# %%
ln.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=ln.predict(x_test)

# %%
ln.intercept_
# Out:
# -76.32194442658383

# %%
ln.coef_
# Out:
# array([-6.10433240e-05,  6.09500978e-05,  6.11567985e-05,  6.06169516e-05,
#         6.10515011e-05,  6.09127263e-05,  6.26831111e-05,  4.86190294e-01,
#         3.84291520e-02,  3.77320761e-04])

# %%
Rsquare = ln.score(x_test , y_test)     #Rsquare
print("Rsquare of the model is :", Rsquare)
# Out:
# Rsquare of the model is : 0.4120776811830529

# %%
# Adjusted Rsquare
# formula : 1 - (1 - Rsquare) * (N - 1) / (N - k - 1)

N = x_train.shape[0]
k = x_train.shape[1]

Adj_Rsquare = 1 - (1 - Rsquare) * (N - 1) / (N - k - 1)
Adj_Rsquare
# Out:
# 0.41167466341583536

# %%
pred_train = ln.predict(x_train)
len(pred_train)
# Out:
# 14599

# %%
pred_train
# Out:
# array([1.69109228, 1.65019084, 1.18865728, ..., 1.6386025 , 1.65600139,
#        1.19923343])

# %%
error_train = y_train - pred_train
error_train
# Out:
# 14   -0.011092
# 49   -0.200191
# 26    0.051343
# 13    0.405031
# 22    0.160682
#         ...
# 26    0.600134
# 27   -0.082475
# 30   -0.258602
# 30    0.683999
# 24    0.190767
# Name: Avg_Price, Length: 14599, dtype: float64

# %%
pred_test=ln.predict(x_test)

# %%
error_test = y_test - pred_test
error_train
# Out:
# 14   -0.011092
# 49   -0.200191
# 26    0.051343
# 13    0.405031
# 22    0.160682
#         ...
# 26    0.600134
# 27   -0.082475
# 30   -0.258602
# 30    0.683999
# 24    0.190767
# Name: Avg_Price, Length: 14599, dtype: float64

# %%
ln.intercept_
# Out:
# -76.32194442658383

# %%
import numpy as np

MSE = np.mean(np.square(error_test))
MSE
# Out:
# 0.09786848464922733

# %%
RMSE = np.sqrt(np.mean(np.square(error_test)))
RMSE
# Out:
# 0.3128393911406096

# %%
MAPE = np.mean(np.absolute(error_test * 100 / y_test))
MAPE
# Out:
# 18.32192220137806

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#checking assumption of error term normally distributed
plt.hist(error_test , bins=15);

# %%
sns.distplot(error_test)

# %%
plt.figure(figsize=(10,10))
plt.plot(error_test , "*")
plt.axhline(y = np.mean(error_test) , color = "black")
plt.axhline(y = 3 , color = "g")
plt.axhline(y = -3 , color = "r")

# %%
plt.figure(figsize=(8,8))
plt.scatter(y_train , pred_train , marker="*")
plt.xlabel("Actual Values" , size = 15)
plt.ylabel("Predicted Values" , size = 15)
plt.title("Actual Vs Predicted Values" , size = 15)
# Out:
# Text(0.5, 1.0, 'Actual Vs Predicted Values')

# %%
def remove_outliers(df,col,k=2):
    mean=df[col].mean()
    global df1
    sd=df[col].std()
    final_list= [x for x in df[col] if (x > mean - k*sd)]
    final_list= [x for x in df[col] if (x > mean - k*sd)]
    df1=df.loc[df[col].isin(final_list)] ; print(df1.shape) ; return df1

# %%
remove_outliers(df,'Total Volume',k=3)
# Out:
# (18249, 11)
#     Total Volume     4046       4225    4770  Small Bags  Large Bags  \
# 0       64236.62  1036.74   54454.85   48.16     8603.62       93.25
# 1       54876.98   674.28   44638.81   58.33     9408.07       97.49
# 2      118220.22   794.70  109149.67  130.50     8042.21      103.14
# 3       78992.15  1132.00   71976.41   72.58     5677.40      133.76
# 4       51039.60   941.48   43838.39   75.78     5986.26      197.69
# ..           ...      ...        ...     ...         ...         ...
# 7       17074.83  2046.96    1529.20    0.00    13066.82      431.85
# 8       13888.04  1191.70    3431.50    0.00     8940.04      324.80
# 9       13766.76  1191.92    2452.79  727.94     9351.80       42.31
# 10      16205.22  1527.63    2981.04  727.01    10919.54       50.00
# 11      17489.58  2894.77    2356.13  224.53    11988.14       26.01
#
#     XLarge Bags  type  year  region  Avg_Price
# 0           0.0     0  2015       0       1.33
# ...

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(x_train,y_train)
# Out:
# C:\Users\tanma\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.00659010193567, tolerance: 0.2351242726296322
#   positive)
# Lasso()

# %%
lasso.coef_  ##can use for feature selection
# Out:
# array([-3.98500423e-08, -7.21331737e-08,  1.12084208e-07, -4.44496980e-07,
#         7.36775234e-08, -5.61279944e-08,  1.24438488e-06,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00])

# %%
df.columns
# Out:
# Index(['Total Volume', '4046', '4225', '4770', 'Small Bags', 'Large Bags',
#        'XLarge Bags', 'type', 'year', 'region', 'Avg_Price'],
#       dtype='object')

# %%
fruit_type
# Out:
#       fruit_type  code
# 0   conventional     0
# 1   conventional     0
# 2   conventional     0
# 3   conventional     0
# 4   conventional     0
# ..           ...   ...
# 7        organic     1
# 8        organic     1
# 9        organic     1
# 10       organic     1
# 11       organic     1
#
# [18249 rows x 2 columns]

# %%
region
# Out:
#               region  code
# 0             Albany     0
# 1             Albany     0
# 2             Albany     0
# 3             Albany     0
# 4             Albany     0
# ..               ...   ...
# 7   WestTexNewMexico    53
# 8   WestTexNewMexico    53
# 9   WestTexNewMexico    53
# 10  WestTexNewMexico    53
# 11  WestTexNewMexico    53
#
# [18249 rows x 2 columns]

# %%
##function to actually predict the price
def find_codes():
    reg=str(input('Enter region = '))
    fruittype=str(input('Enter inn1 team= '))
    
    for i in region['region']:
        if i==reg:
            print('code for',i,'is= ',region[region['region']==i])
            break
    for k in fruit_type['fruit_type']:
        if k==fruittype:
            print('code for',k,'is= ',fruit_type[fruit_type['fruit_type']==k])
            break

# %%
find_codes()
# Out:
# Enter region =
# Enter inn1 team=

# %%
def predict_price():
    region_code=int(input('Enter region code'))
    type_code=int(input('Enter type code'))
    Total_Volume=int(input('total volume sold '))
    sold_of_4046=int(input('unit of 4046 sold'))
    sold_of_4225=int(input('unit of 4225 sold'))
    sold_of_4770=int(input('unit of 4770 sold'))
    
    Small_Bags=int(input('Small bags sold '))
    Large_Bags=int(input('Large bags sold '))
    XLarge_Bags=int(input('XLarge bags sold'))
    year=int(input('year '))
    x_pars=pd.DataFrame({'1':[region_code],'2':[type_code],'3':[Total_Volume],'4':[sold_of_4046],'5':[sold_of_4225],'6':[sold_of_4770],'7':[Small_Bags],'8':[Large_Bags],'9':[XLarge_Bags],'10':[year]})
    pred_price=ln.predict(x_pars)
    
    
    print(pred_price)

# %%
predict_price()
# Out:
# Enter region code
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-343794efb6f2> in <module>
# ----> 1 predict_price()
#
# <ipython-input-61-8cf8ddbd80b1> in predict_price()
#       1 def predict_price():
# ----> 2     region_code=int(input('Enter region code'))
#       3     type_code=int(input('Enter type code'))
#       4     Total_Volume=int(input('total volume sold '))
#       5     sold_of_4046=int(input('unit of 4046 sold'))
#
# ValueError: invalid literal for int() with base 10: ''
